# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello, World!")
# Out:
# Hello,''' World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
x=input("input an integer number :")
print (x)
# Out:
# hello

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
while True:
  try:
    x=int(input("input an integer number :"))
    break
  except ValueError:
    print("re input a value please")


if x>0:
  print ("positive")
elif x<0:
    print("negative")
else:
    print("zero")
# Out:
# negative

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here
while True:
  try:
    x, y, z=map(float,input("input a three numbers seperated by space : ").split())
    break
  except ValueError:
    print("re input just numbers only  please!")



print ("the max is", max(x,y,z))
# Out:
# the max is 8.0

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 5:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here
bool_var=True
int_var=4
float_var=5.8
str_var="Joud"
print(bool_var,type(bool_var))
print(int_var,type(int_var))
print(float_var,type(float_var))
print(str_var,type(str_var))
# Out:
# True <class 'bool'>
# 4 <class 'int'>
# 5.8 <class 'float'>
# Joud <class 'str'>

# %% [markdown]
# **Question 6:** Write a Python program to swap the values of two variables.

# %%
# Your code here
x, y= input("input two values separated by space: ").split()
print("the values before swaping is:x= ",x," y=",y)
temp= x 
x=y
y=temp
print("the values after swaping is:x= ",x," y=",y)
x,y=y,x
print("the values after swaping again in another way is:x= ",x," y=",y)
# Out:
# the values before swaping is:x=  jalal  y= 555
# the values after swaping is:x=  555  y= jalal
# the values after swaping again in another way is:x=  jalal  y= 555

# %% [markdown]
# **Question 7:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here
while True:
  try:
    c=float(input("input a temperatrue in celsius  :"))
    break
  except ValueError:
    print("re input just numbers only  please! ")

f=(c * 9/5)+32

print("Temprature in Fahrenheit equal: ",f)
# Out:
# Temprature in Fahrenheit equal:  59.0

# %% [markdown]
# **Question 8:** Write a Python program to concatenate two strings.

# %%
# Your code here
while True:
  try:
    str1, str2 =input("input a two strings  seperated by space : ").split()
    break
  except ValueError:
    print("re input just numbers only  please!")
    
temp=str1+str2
print ("concatinating is : ",temp)
# Out:
# concatinating is :  2222

# %% [markdown]
# **Question 9:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here
my_int=5
my_float=8.4
my_str="jalal"
my_bool=False

print(f"Is my Integer is int? {isinstance(my_int,int)}")
print(f"Is my Float is float? {isinstance(my_float,float)}")
print(f"Is my Boolean is bool? {isinstance(my_str,bool)}")
print(f"Is my String is str? {isinstance(my_str,int)}")
# Out:
# Is my Integer is int? True
# Is my Float is float? True
# Is my Boolean is bool? False
# Is my String is str? False

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 10:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
while True:
  try:
    x, y=map(float,input("input a two numbers seperated by space : ").split())
    break
  except ValueError:
    print("re input just numbers only  please!")

print(f" The sum is {x+y} \n The Subtraction is {x-y} \n The Multiplication is {x*y} \n The Division is {x/y}")
# Out:
#  The sum is 29.0
#  The Subtraction is 11.0
#  The Multiplication is 180.0
#  The Division is 2.2222222222222223

# %% [markdown]
# **Question 11:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here
while True:
  try:
    x, y=map(float,input("input a two numbers seperated by space : ").split())
    break
  except ValueError:
    print("re input just numbers only  please!")

if x>y:
    print(f"{x} is greater than {y}")
elif x<y:
    print(f"{x} is smaller than {y}")
else:
    print(f"{x} is equal {y}")
# Out:
# 44.0 is greater than 33.0

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here
x= True
y= False
    
print(f"x and y is {x and y}\n x or y is {x or y}\n not x  is {not x} \n not y  is {not y}" )
# Out:
# x and y is False
#  x or y is True
#  not x  is False
#  not y  is True

# %% [markdown]
# **Question 13:** Write a Python program to calculate the square of a number.

# %%
# Your code here
while True:
  try:
    x=float(input("input a  number : "))
    break
  except ValueError:
    print("re input just a number only  please!")
print (f"Square of {x} using multiplication {x}*{x} = {x*x}\n  Square of {x} using exponentiation {x}**2 ={x ** 2 }")
# Out:
# re input just numbers only  please!
# Square of 0.0 using multiplication 0.0*0.0 = 0.0
#   Square of 0.0 using exponentiation 0.0**2 =0.0

# %% [markdown]
# **Question 14:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
while True:
  try:
    x=int(input("input a positive number : "))
    break
  except ValueError:
    print("re input just positive number only  please!")
    
if x%2==0:
    print(f"{x} is even")
else:
    print(f"{x} is odd")
# Out:
# 120 is even

# %% [markdown]
# **Question 15:** Write a Python program to reverse a string.

# %%
# Your code here

str=input("input a String number : ")

reversed_str= str[ : : -1]
print(f" The reversed String of {str} is {reversed_str}")

## another method using for
rev_str=""
for c in str: # c refers to one character in string
    rev_str=c+rev_str
print(f" The reversed String of {str} is {rev_str}   {"".join(reversed(str))}")

## another method using the function reversed()
    
print(f" The reversed String of {str} is {"".join(reversed(str))}")
# Out:
#  The reversed String of مراحب is بحارم
#  The reversed String of مراحب is بحارم   بحارم
#  The reversed String of مراحب is بحارم
